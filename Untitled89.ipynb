# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=400,n_features=1,n_informative=1,noise=1.8,random_state=11)

# %%
plt.scatter(x,y)

# %%
x,y=make_regression(n_samples=400,n_features=1,n_informative=1,noise=1.8,random_state=11)
def lwr(x,y):
    y=y.reshape((-1,1))
    y=np.mat(y)
    x=np.hstack((x,np.ones((x.shape[0],1))))
    xt=np.transpose(x)
    first=np.dot(xt,x)
    second=np.dot(xt,y)
    theta=np.linalg.inv(first)*second
    print(type(np.linalg.inv(first)))
    return np.dot(x,theta)


#x=np.hstack((x,np.ones((x.shape[0],1))))
y=y.reshape((-1,1))
#y=np.mat(y)
plt.scatter(x,y)
plt.plot(x,lwr(x,y_),color='orange')
plt.show()
# Out:
# <class 'numpy.ndarray'>
